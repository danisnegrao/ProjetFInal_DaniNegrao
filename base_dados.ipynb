# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df_dados = pd.read_csv('saude_sexual_feminina.csv')
df_dados
# Out:
#              Carimbo de data/hora Como Gostaria de ser chamada?        IDADE:  \
# 0     2023/11/24 6:33:58 PM GMT-3                    para(noia)  25 - 34 anos
# 1     2023/11/24 7:02:13 PM GMT-3                         Nanda  18 - 24 anos
# 2     2023/11/24 7:02:30 PM GMT-3                        Júlia   25 - 34 anos
# 3     2023/11/24 7:06:07 PM GMT-3                       Letícia  25 - 34 anos
# 4     2023/11/24 7:07:42 PM GMT-3          Mariposa Apaixonada   35 - 44 anos
# ..                            ...                           ...           ...
# 218   2023/11/28 6:58:15 PM GMT-3             Jessica Ferreira   25 - 34 anos
# 219  2023/11/28 11:16:46 PM GMT-3                         Lana   18 - 24 anos
# 220   2023/11/29 4:04:27 AM GMT-3                       Larissa  18 - 24 anos
# 221   2023/11/30 1:55:01 PM GMT-3                          Jake  25 - 34 anos
# 222   2023/11/30 2:34:22 PM GMT-3                 Suellen Costa  35 - 44 anos
#
# ...

# %%
df_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 40 columns):
#  #   Column                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                           --------------  -----
#  0   Carimbo de data/hora                                                                             223 non-null    object
#  1   Como Gostaria de ser chamada?                                                                    223 non-null    object
#  2   IDADE:                                                                                           223 non-null    object
#  3   ESTADO CIVIL:                                                                                    223 non-null    object
#  4   NÍVEL EDUCACIONAL:                                                                               223 non-null    object
# ...
